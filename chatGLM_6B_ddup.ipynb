# %% [markdown]
# <a href="https://colab.research.google.com/github/tigerywh/colab/blob/master/chatGLM_6B_ddup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **chatGLM部署在colab上的脚本。**

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !git clone https://github.com/THUDM/ChatGLM-6B.git
# Out:
# fatal: destination path 'ChatGLM-6B' already exists and is not an empty directory.

# %%
# %ls
# %cd ChatGLM-6B
# %ls
# Out:
# ChatGLM-6B/  sample_data/
# /content/ChatGLM-6B
# api.py       LICENSE        ptuning/          resources/       web_demo.py
# cli_demo.py  limitations/   README_en.md      utils.py
# examples/    MODEL_LICENSE  README.md         web_demo2.py
# improve/     PROJECT.md     requirements.txt  web_demo_old.py

# %%
# %pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 95.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 416.6/416.6 kB 49.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 68.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 kB 31.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 114.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 31.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.7/129.7 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.2/286.2 kB 39.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# 查看当前的GPU情况

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Apr 26 08:21:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   76C    P0    36W /  70W |   7961MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# 查看当前的内存使用情况

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %% [markdown]
# 命令行方式交互

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm-6b-int4-qe", trust_remote_code=True)
model = AutoModel.from_pretrained("THUDM/chatglm-6b-int4-qe", trust_remote_code=True).half().cuda()
model = model.eval()
response, history = model.chat(tokenizer, "你好", history=[])
print(response)
# Out:
# ...
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# No compiled kernel found.
# Compiling kernels : /root/.cache/huggingface/modules/transformers_modules/THUDM/chatglm-6b-int4-qe/977d9df4cfae6b7a756e07698483872c5c070eee/quantization_kernels.c
# ...

# %%
response, history = model.chat(tokenizer, "写首赞美春天的诗，浪漫风格", history=history)

# %%
print(response)
# Out:
# 春天啊，你的美丽
# 如同鲜花绽放的大地
# 和风轻拂，万物复苏
# 让我们心中充满了喜悦和感激
#
# 春天啊，你的温暖
# 如同阳光照耀的家
# 让我的心充满温馨和安宁
# 让我们心中充满了爱意和感激
#
# 春天啊，你的奇妙
# 如同多彩世界的吸引力
# 让我们沉浸在童话般的世界中
# 享受这美好的时光
#
# 春天啊，你是我心中的女神
# 为我们带来了无尽的喜悦和希望
# 让我们一起颂扬你的美丽和神奇
# 春天啊，你是我的永恒的挚爱。

# %%
response, history = model.chat(tokenizer, "给华为的水机产品写一段广告并列举5个亮点", history=history)

# %%
print(response)
# Out:
# 华为的水机产品，让家庭更加智能和健康。以下是5个亮点：
#
# 1. 智能感应：水机能够智能感应水质的好坏，自动启动或停止工作，保障水质安全和持续使用。
#
# 2. 高效节能：水机采用高效节能设计，根据不同的用水情况和模式，可以智能调整功率和工作时间，节约用水。
#
# 3. 声音控制：水机可以通过声音控制，根据不同的用水场景和模式，播放音乐、调节温度等，提高用水体验。
#
# 4. 远程监控：水机可以通过手机APP远程监控和管理，随时随地了解水质情况和用水情况，提前预防水质问题。
#
# 5. 多样化模式：水机有多种不同的模式，如高温保温、低温保温、温度调节、过滤模式等，根据不同的用水需求和情况，选择不同的模式，实现不同的用水效果。
#
# 华为的水机产品，智能、高效、节能、声音控制和多样化模式，为家庭提供更加健康、智能和舒适的用水体验。

# %% [markdown]
# 安装webui的依赖

# %%
# !pip install gradio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Web方式交互 启动webui

# %%
from transformers import AutoModel, AutoTokenizer
import gradio as gr

tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm-6b-int4-qe", trust_remote_code=True)
model = AutoModel.from_pretrained("THUDM/chatglm-6b-int4-qe", trust_remote_code=True).quantize(4).half().cuda()
model = model.eval()

MAX_TURNS = 20
MAX_BOXES = MAX_TURNS * 2


def predict(input, history=None):
    if history is None:
        history = []
    response, history = model.chat(tokenizer, input, history)
    updates = []
    for query, response in history:
        updates.append(gr.update(visible=True, value="用户：" + query))
        updates.append(gr.update(visible=True, value="ChatGLM-6B：" + response))
    if len(updates) < MAX_BOXES:
        updates = updates + [gr.Textbox.update(visible=False)] * (MAX_BOXES - len(updates))
    return [history] + updates


with gr.Blocks() as demo:
    state = gr.State([])
    text_boxes = []
    for i in range(MAX_BOXES):
        if i % 2 == 0:
            text_boxes.append(gr.Markdown(visible=False, label="提问："))
        else:
            text_boxes.append(gr.Markdown(visible=False, label="回复："))

    with gr.Row():
        with gr.Column(scale=4):
            txt = gr.Textbox(show_label=False, placeholder="Enter text and press enter").style(container=False)
        with gr.Column(scale=1):
            button = gr.Button("Generate")
    button.click(predict, [txt, state], [state] + text_boxes)
demo.queue().launch(share=True, inbrowser=True)
# Out:
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# No compiled kernel found.
# Compiling kernels : /root/.cache/huggingface/modules/transformers_modules/THUDM/chatglm-6b-int4-qe/977d9df4cfae6b7a756e07698483872c5c070eee/quantization_kernels.c
# ...

# %%
# !sudo apt install iputils-ping
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   iputils-ping
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 40.1 kB of archives.
# After this operation, 108 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 iputils-ping amd64 3:20190709-3 [40.1 kB]
# Fetched 40.1 kB in 5s (7,961 B/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package iputils-ping.
# ...

# %%
# !curl ipecho.net/plain
# Out:
# 34.87.85.153
